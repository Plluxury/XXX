# %% [markdown]
# <a href="https://colab.research.google.com/github/Plluxury/XXX/blob/main/cr1_mo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('telecom_churn.csv')

# %%
data
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# 5       AL             118        510                Yes              No
# 6       MA             121        510                 No             Yes
# 7       MO             147        415                Yes              No
# 8       LA             117        408                 No              No
# 9       WV             141        415                Yes             Yes
# 10      IN              65        415                 No              No
# 11      RI              74        415                 No              No
# ...

# %%
#Первое задание
len(data['State'].unique())
# Out:
# 51

# %%
#Второе задание
data['Account length'].mean()
# Out:
# 101.06480648064806

# %%
#Третье задание
a = data[['International plan','Churn']]
race = a[a['International plan']=='Yes']
race = race['Churn'] == True
race.value_counts(True)
# Out:
# False    0.575851
# True     0.424149
# Name: Churn, dtype: float64

# %%
#Четвертое задание
a = data['Total day minutes']
print(a.mean(), a.std())
# Out:
# 179.77509750975094 54.46738920237137

# %%
#Пятое задание
w = data[data['Churn']== False]
if w['Total day minutes'].mean() > w['Total eve minutes'].mean():
    print(True)
else: print(False)
# Out:
# False

# %%
#6
a = data['State'].unique()
for i in a:
    b = data[data['State']== i ]
    print(i, 'DM:',round(b['Total day minutes'].mean()), 'EM:',round(b['Total eve minutes'].mean()))
# Out:
# KS DM: 192.0 EM: 203.0
# OH DM: 183.0 EM: 206.0
# NJ DM: 196.0 EM: 198.0
# OK DM: 180.0 EM: 193.0
# AL DM: 186.0 EM: 195.0
# MA DM: 180.0 EM: 215.0
# MO DM: 171.0 EM: 200.0
# LA DM: 178.0 EM: 198.0
# WV DM: 174.0 EM: 188.0
# IN DM: 197.0 EM: 203.0
# RI DM: 167.0 EM: 211.0
# IA DM: 178.0 EM: 206.0
# MT DM: 174.0 EM: 202.0
# NY DM: 175.0 EM: 197.0
# ID DM: 179.0 EM: 195.0
# VT DM: 182.0 EM: 205.0
# VA DM: 177.0 EM: 204.0
# TX DM: 182.0 EM: 200.0
# FL DM: 180.0 EM: 210.0
# CO DM: 179.0 EM: 207.0
# AZ DM: 172.0 EM: 188.0
# SC DM: 166.0 EM: 207.0
# NE DM: 177.0 EM: 203.0
# WY DM: 180.0 EM: 206.0
# HI DM: 176.0 EM: 191.0
# IL DM: 174.0 EM: 197.0
# NH DM: 177.0 EM: 198.0
# GA DM: 185.0 EM: 204.0
# AK DM: 178.0 EM: 184.0
# MD DM: 197.0 EM: 196.0
# AR DM: 176.0 EM: 201.0
# WI DM: 179.0 EM: 197.0
# OR DM: 176.0 EM: 201.0
# MI DM: 181.0 EM: 208.0
# DE DM: 175.0 EM: 208.0
# UT DM: 184.0 EM: 195.0
# CA DM: 184.0 EM: 199.0
# MN DM: 183.0 EM: 199.0
# SD DM: 190.0 EM: 203.0
# NC DM: 185.0 EM: 203.0
# ...

# %%
#7
data_d = data[['Churn', 'International plan']]
data_d
# Out:
#       Churn International plan
# 0     False                 No
# 1     False                 No
# 2     False                 No
# 3     False                Yes
# 4     False                Yes
# 5     False                Yes
# 6     False                 No
# 7     False                Yes
# 8     False                 No
# 9     False                Yes
# 10     True                 No
# 11    False                 No
# 12    False                 No
# 13    False                 No
# 14    False                 No
# 15     True                 No
# 16    False                 No
# 17    False                 No
# 18    False                 No
# 19    False                 No
# 20    False                 No
# 21     True                 No
# 22    False                 No
# 23    False                 No
# 24    False                 No
# 25    False                 No
# 26    False                 No
# 27    False                 No
# 28    False                 No
# ...

# %%
y = data_d[data_d['Churn']==True]
y = y['International plan'] == 'Yes'
y.value_counts(True)
# Out:
# False    0.716356
# True     0.283644
# Name: International plan, dtype: float64

# %%
n = data_d[data_d['Churn']==False]
n = n['International plan'] == 'Yes'
n.value_counts(True)
# Out:
# False    0.934737
# True     0.065263
# Name: International plan, dtype: float64

# %%
#8
data_d = data[['Total day minutes', 'Total eve minutes','Total night minutes']]

# %%
data_d
# Out:
#       Total day minutes  Total eve minutes  Total night minutes
# 0                 265.1              197.4                244.7
# 1                 161.6              195.5                254.4
# 2                 243.4              121.2                162.6
# 3                 299.4               61.9                196.9
# 4                 166.7              148.3                186.9
# 5                 223.4              220.6                203.9
# 6                 218.2              348.5                212.6
# 7                 157.0              103.1                211.8
# 8                 184.5              351.6                215.8
# 9                 258.6              222.0                326.4
# 10                129.1              228.5                208.8
# 11                187.7              163.4                196.0
# 12                128.8              104.9                141.1
# 13                156.6              247.6                192.3
# ...

# %%
q = round((sum(data_d['Total day minutes']) +sum(data_d['Total eve minutes'])  + sum(data_d['Total night minutes']))/3333,2)
q
# Out:
# 581.63

# %%
lenth = []
for i in range(3333):
    if data_d['Total day minutes'][i]+data_d['Total eve minutes'][i]+data_d['Total night minutes'][i]>q:
        lenth.append(1)
print('У',len(lenth),'человек больше минут')
# Out:
# У 1695 человек больше минут

# %%
#9
data_d = data[['Churn', 'Customer service calls']]
data_d
# Out:
#       Churn  Customer service calls
# 0     False                       1
# 1     False                       1
# 2     False                       0
# 3     False                       2
# 4     False                       3
# 5     False                       0
# 6     False                       3
# 7     False                       0
# 8     False                       1
# 9     False                       0
# 10     True                       4
# 11    False                       0
# 12    False                       1
# 13    False                       3
# 14    False                       4
# 15     True                       4
# 16    False                       1
# 17    False                       3
# 18    False                       1
# 19    False                       1
# 20    False                       0
# 21     True                       5
# 22    False                       0
# 23    False                       2
# 24    False                       0
# ...

# %%
y = data_d[data_d['Churn']==True]
round(y['Customer service calls'].mean(), 2)
# Out:
# 2.23

# %%
n = data_d[data_d['Churn']==False]
round(n['Customer service calls'].mean(), 2)
# Out:
# 1.45
